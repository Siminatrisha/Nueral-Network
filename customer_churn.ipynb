# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
import pandas as pd
# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_csv("/content/drive/MyDrive/WA_Fn-UseC_-Telco-Customer-Churn.csv")
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# Here, monthly charge is in float but TotalCharges is in object.So, we need to convert it into float type

# %%
pd.to_numeric(data.TotalCharges,errors='coerce')
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %% [markdown]
# errors=coerce basically drop the " " null and spaced columns

# %%
data[pd.to_numeric(data.TotalCharges,errors='coerce').isnull()]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %% [markdown]
# in all these rows the totalcharge value is null and we are dropping these.

# %%
df=data[data.TotalCharges!=' ']
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.shape
# Out:
# (7032, 21)

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.TotalCharges=pd.to_numeric(df.TotalCharges)
# Out:
# <ipython-input-11-97ac71a190df>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.TotalCharges=pd.to_numeric(df.TotalCharges)

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
tenure_no = df[df.Churn=='No'].tenure
tenure_yes = df[df.Churn=='Yes'].tenure
tenure_yes
# Out:
# 2        2
# 4        2
# 5        8
# 8       28
# 13      49
#         ..
# 7021    12
# 7026     9
# 7032     1
# 7034    67
# 7041     4
# Name: tenure, Length: 1869, dtype: int64

# %%
tenure_no = df[df.Churn=='No'].tenure
tenure_yes = df[df.Churn=='Yes'].tenure
plt.xlabel("tenure")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction Visualiztion")
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]
plt.hist([tenure_yes, tenure_no], rwidth=0.95, color=['yellow','blue'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
df.drop('customerID',axis='columns',inplace=True)
# Out:
# <ipython-input-14-bd6e5fce557e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('customerID',axis='columns',inplace=True)

# %%
def print_unique_col_values(df):
  for column in df:
    if df[column].dtype=='object':
      print(f'{column}:{df[column].unique()}')

# %%
print_unique_col_values(df)
# Out:
# gender:['Female' 'Male']
# Partner:['Yes' 'No']
# Dependents:['No' 'Yes']
# PhoneService:['No' 'Yes']
# MultipleLines:['No phone service' 'No' 'Yes']
# InternetService:['DSL' 'Fiber optic' 'No']
# OnlineSecurity:['No' 'Yes' 'No internet service']
# OnlineBackup:['Yes' 'No' 'No internet service']
# DeviceProtection:['No' 'Yes' 'No internet service']
# TechSupport:['No' 'Yes' 'No internet service']
# StreamingTV:['No' 'Yes' 'No internet service']
# StreamingMovies:['No' 'Yes' 'No internet service']
# Contract:['Month-to-month' 'One year' 'Two year']
# PaperlessBilling:['Yes' 'No']
# PaymentMethod:['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn:['No' 'Yes']

# %%
df.replace('No internet service','No',inplace=True)
df.replace('No phone service','No',inplace=True)
# Out:
# <ipython-input-17-1fed3bd488c1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace('No internet service','No',inplace=True)
# <ipython-input-17-1fed3bd488c1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace('No phone service','No',inplace=True)

# %%
print_unique_col_values(df)
# Out:
# gender:['Female' 'Male']
# Partner:['Yes' 'No']
# Dependents:['No' 'Yes']
# PhoneService:['No' 'Yes']
# MultipleLines:['No' 'Yes']
# InternetService:['DSL' 'Fiber optic' 'No']
# OnlineSecurity:['No' 'Yes']
# OnlineBackup:['Yes' 'No']
# DeviceProtection:['No' 'Yes']
# TechSupport:['No' 'Yes']
# StreamingTV:['No' 'Yes']
# StreamingMovies:['No' 'Yes']
# Contract:['Month-to-month' 'One year' 'Two year']
# PaperlessBilling:['Yes' 'No']
# PaymentMethod:['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn:['No' 'Yes']

# %%
df['gender'].replace({'Female':1,'Male':0},inplace=True)
# Out:
# <ipython-input-19-7f2ac4c24de4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender'].replace({'Female':1,'Male':0},inplace=True)

# %%
df['gender'].unique()
# Out:
# array([1, 0])

# %%
df1=pd.get_dummies(data=df, columns=['InternetService','Contract','PaymentMethod'])

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for col in yes_no_columns:
    df1[col].replace({'Yes': 1,'No': 0},inplace=True)

# %%
for col in df1:
  print(f'{col}:{df1[col].unique()}')
# Out:
# gender:[1 0]
# SeniorCitizen:[0 1]
# Partner:[1 0]
# Dependents:[0 1]
# tenure:[ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService:[0 1]
# MultipleLines:[0 1]
# OnlineSecurity:[0 1]
# OnlineBackup:[1 0]
# DeviceProtection:[0 1]
# TechSupport:[0 1]
# StreamingTV:[0 1]
# StreamingMovies:[0 1]
# PaperlessBilling:[1 0]
# MonthlyCharges:[29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges:[  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn:[0 1]
# InternetService_DSL:[1 0]
# InternetService_Fiber optic:[0 1]
# InternetService_No:[0 1]
# Contract_Month-to-month:[1 0]
# Contract_One year:[0 1]
# Contract_Two year:[0 1]
# PaymentMethod_Bank transfer (automatic):[0 1]
# PaymentMethod_Credit card (automatic):[0 1]
# PaymentMethod_Electronic check:[1 0]
# PaymentMethod_Mailed check:[0 1]

# %%
df1.sample(3)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 1732       0              1        1           1      61             1
# 1997       1              0        1           1      67             1
# 446        1              0        0           0       1             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 1732              1               0             1                 0  ...
# 1997              1               0             0                 1  ...
# 446               0               0             0                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 1732                    0                            1                   0
# 1997                    0                            1                   0
# 446                     0                            1                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']
df1[cols_to_scale] = scaler.fit_transform(df1[cols_to_scale])

# %%
df1.sample()
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 2030       0              0        0           1  0.014085             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 2030              1               1             1                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 2030                    1                            0                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 2030                        1                  0                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 2030                                        1
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 2030                                      0                               0
#
#       PaymentMethod_Mailed check
# 2030                           0
#
# [1 rows x 27 columns]

# %%
X= df1.drop('Churn',axis='columns')
y=df1['Churn']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2, random_state=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0a3e68be8eaa> in <cell line: 2>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2, random_state=10)
#
# NameError: name 'X' is not defined

# %%
X_train.shape
# Out:
# (5625, 26)

# %%
X_test.shape
# Out:
# (1407, 26)

# %%
X_train[:5]
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 4954       0              0        0           1  0.000000             1
# 3918       0              0        1           1  0.267606             1
# 5406       0              0        1           1  0.985915             1
# 1637       0              0        0           0  0.915493             0
# 5191       1              0        1           1  0.309859             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 4954              0               0             0                 0  ...
# 3918              0               0             0                 0  ...
# 5406              1               1             0                 0  ...
# 1637              0               0             0                 0  ...
# 5191              1               1             1                 1  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# ...

# %% [markdown]
# Build Model

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model= keras.Sequential(
    [keras.layers.Dense(26, input_shape=(26,), activation='relu'),
    keras.layers.Dense(20, activation='relu'),
keras.layers.Dense(1,activation='sigmoid')
    ]
)
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 1s 2ms/step - loss: 0.4991 - accuracy: 0.7573
# Epoch 2/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4397 - accuracy: 0.7842
# Epoch 3/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4319 - accuracy: 0.7934
# Epoch 4/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4268 - accuracy: 0.7948
# Epoch 5/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4228 - accuracy: 0.7986
# Epoch 6/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4202 - accuracy: 0.7991
# Epoch 7/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4187 - accuracy: 0.8030
# Epoch 8/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4171 - accuracy: 0.8032
# Epoch 9/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4151 - accuracy: 0.8059
# Epoch 10/100
# ...

# %%
model.evaluate(X_test,y_test)
# Out:
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4398 - accuracy: 0.7918
# [0.4398154318332672, 0.7917554974555969]

# %%
yp=model.predict(X_test)
# Out:
# 44/44 [==============================] - 0s 1ms/step

# %%
yp[:10]
# Out:
# array([[0.00770363],
#        [0.00433974],
#        [0.2798205 ],
#        [0.04019746],
#        [0.01952036],
#        [0.07115393],
#        [0.6813418 ],
#        [0.00418089],
#        [0.33807766],
#        [0.18124609]], dtype=float32)

# %%
y_pred=[]
for i in yp:
  if i> 0.5:
    y_pred.append(1)
  else:
    y_pred.append(0)

# %%
y_pred[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f2f4ca26448f> in <cell line: 1>()
# ----> 1 y_pred[:10]
#
# NameError: name 'y_pred' is not defined

# %%
y_test[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-afb1297a6a30> in <cell line: 1>()
# ----> 1 y_test[:10]
#
# NameError: name 'y_test' is not defined
